# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/7f/b1/7f4c14026334a6f7be62a86ab4b545dbea2c5ef9308b7d72c0d4bb0f7ff8/ultralytics-8.0.232-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 12.1 MB/s eta 0:00:00
# ...

# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5310.5/8062.4 GB disk)

# %%
# !touch custom_data.yaml
# !echo 'train: /kaggle/input/forest-fire-and-smoke-2nd-dataset/Fireyolov8/train/images' >> custom_data.yaml
# !echo 'val: /kaggle/input/forest-fire-and-smoke-2nd-dataset/Fireyolov8/valid/images' >> custom_data.yaml
# !echo 'test: /kaggle/input/forest-fire-and-smoke-2nd-dataset/Fireyolov8/test/images' >> custom_data.yaml
# !echo 'nc: 2' >> custom_data.yaml
# !echo "names: ['Fire', 'Smoke']" >> custom_data.yaml

# View custom_data.yaml file
# !cat custom_data.yaml
# Out:
# train: /kaggle/input/forest-fire-and-smoke-2nd-dataset/Fireyolov8/train/images
# val: /kaggle/input/forest-fire-and-smoke-2nd-dataset/Fireyolov8/valid/images
# test: /kaggle/input/forest-fire-and-smoke-2nd-dataset/Fireyolov8/test/images
# nc: 2
# names: ['Fire', 'Smoke']

# %%
# !yolo task=detect mode=train model=yolov8x.pt imgsz=640 data=/kaggle/working/custom_data.yaml epochs=100
# Out:
# ...
# 100%|████████████████████████████████████████| 131M/131M [00:02<00:00, 48.9MB/s]
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...
